# %% [markdown]
# <a href="https://colab.research.google.com/github/testingmyangels/Homeworks-for-Modeling/blob/master/s2_ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = 0
count = 0
while num <= 19:
    if num % 3 == 0:
     count += 1
    num +=1
print("Numbers divisible by 3: ", count)
# Out:
# Numbers divisible by 3:  7

# %%
import random
for i in range(10):
    x = random.random()
    print(x)
# Out:
# 0.4516317614024359
# 0.4311157716037398
# 0.30436990707701783
# 0.6764492729912115
# 0.3027560855401802
# 0.24316064420136252
# 0.7976881067855025
# 0.2801030241630983
# 0.5016547257036628
# 0.11511553311664036
