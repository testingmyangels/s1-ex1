# %% [markdown]
# <a href="https://colab.research.google.com/github/testingmyangels/s1-ex1/blob/master/HomeworkS1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = 18

if age >= 18:
    print("You are an adult")
else:
    print("You are a minor")
# Out:
# You are an adult
